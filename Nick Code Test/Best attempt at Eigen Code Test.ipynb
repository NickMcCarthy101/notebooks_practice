# %%
import numpy as np 
import re 
import os #miscellaneous operating system interfaces 
from collections import Counter

# %%
os.getcwd() #operating system dependent functionality. Finds out what directory we're operating in..
# Out:
# '/home/nick.mccarthy/Desktop/Python Coding & ML/Nick Code Test'

# %%
splitter = "hello my name is dan".split()
splitter
# Out:
# ['hello', 'my', 'name', 'is', 'dan']

# %%
Counter(splitter)
# Out:
# Counter({'dan': 1, 'hello': 1, 'is': 1, 'my': 1, 'name': 1})

# %%
lines = open(os.path.join(os.getcwd(),'doc1.txt'), 'r').readlines()
#lines

# %%
#one way of opening and counting words
with open('doc1.txt') as f: 
    collection = f.read()
    
words = re.findall(r'\w+', collection)
word_counts = Counter(words)
word_counts
# Out:
# Counter({'000': 1,
#          '13': 1,
#          '2008': 1,
#          'a': 62,
#          'able': 3,
#          'about': 8,
#          'abraham': 1,
#          'absence': 1,
#          'accept': 1,
#          'accepted': 1,
#          'access': 1,
#          'accountability': 1,
#          'achievement': 1,
#          'across': 1,
#          'active': 1,
#          'adapting': 1,
#          'admit': 1,
#          'advice': 1,
#          'afford': 2,
#          'affordable': 1,
#          'after': 5,
#          'again': 1,
#          'against': 2,
#          'age': 1,
#          'ago': 1,
#          'all': 18,
#          'alliances': 1,
#          'allow': 1,
#          'alone': 1,
#          'already': 1,
#          'also': 1,
#          'alternative': 1,
#          'although': 1,
#          'am': 1,
#          'america': 9,
#          'american': 2,
#          'americans': 3,
#          'amount': 1,
#          'an': 8,
#          'and': 103,
#          'announce': 1,
# ...

# %%
words = re.findall(r'\w', File1) #only really that useful if it's a string, not if we're just wanting to open a file. 
words #prints the characters within the
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9283a661ec61> in <module>()
# ----> 1 words = re.findall(r'\w', File1) #only really that useful if it's a string, not if we're just wanting to open a file.
#       2 words #prints the characters within the
#
# NameError: name 'File1' is not defined

# %%
s = open('doc1.txt','r') #opens the doc.The first bit is the file object, the second is the file 'mode' [read, write, apending, r+..]
# s is the filename

# %%
from collections import Counter 
def main():
    #Use open() for opening a file
    #Always use 'with' statement as it'll automatically close the file for you 
    with open(r'C:\\Users\\nick.mccarthy\\Desktop\\Nick Code Test\\doc1.txt') as f: 
        #create a list of all words fetched from the file using a list comprehension 
        words = [word for line in f for word in line.split()]
        #now use collections.Counter
        c = Counter(words)
        for word, count in c.most_common(20):
            print (word, count)
main()
