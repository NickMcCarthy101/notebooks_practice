# %%
import numpy 
import re #reg ex 
import os 
from collections import Counter 
import nltk, re, pprint
from nltk import word_tokenize
from nltk.corpus import treebank 
from nltk.tokenize import RegexpTokenizer

# %%
os.getcwd()
# Out:
# '/home/nick.mccarthy/Desktop/Python Coding & ML/Nick Code Test'

# %%
#lines_1 = open(os.path.join(os.getcwd(),'doc1.txt'), 'r').readlines()
#lines
#type(lines1)

# %%
raw_1 = open('doc1.txt').read()
 #type(raw_1)

# %%
tokens_1 = word_tokenize(raw_1)
tokens_1
#words_lower = [w.lower() for w in tokens] --- don't need, because the word_tokenize makes them lowercase
# Out:
# ['let',
#  'me',
#  'begin',
#  'by',
#  'saying',
#  'thanks',
#  'to',
#  'all',
#  'you',
#  'who',
#  "'ve",
#  'traveled',
#  ',',
#  'from',
#  'far',
#  'and',
#  'wide',
#  ',',
#  'to',
#  'brave',
#  'the',
#  'cold',
#  'today',
#  '.',
#  'we',
#  'all',
#  'made',
#  'this',
#  'journey',
#  'for',
#  'a',
#  'reason',
#  '.',
#  'it',
#  "'s",
#  'humbling',
#  ',',
#  'but',
#  'in',
#  'my',
#  'heart',
#  'i',
#  'know',
#  'you',
#  'did',
#  "n't",
#  'come',
#  'here',
#  'just',
#  'for',
#  'me',
#  ',',
#  'you',
#  'came',
#  'here',
#  'because',
#  'you',
#  'believe',
#  'in',
#  'what',
#  'this',
#  'country',
#  'can',
#  'be',
#  '.',
#  'in',
#  'the',
#  'face',
#  'of',
#  'war',
#  ',',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'peace',
#  '.',
#  'in',
#  'the',
#  'face',
#  'of',
#  'despair',
#  ',',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'hope',
#  '.',
#  'in',
#  'the',
#  'face',
#  'of',
#  'a',
# ...

# %%
tokenizer = RegexpTokenizer(r'\w+')
tokens_2 = tokenizer.tokenize(raw_1)
tokens_2 #This one has got rid of punctuation
# Out:
# ['let',
#  'me',
#  'begin',
#  'by',
#  'saying',
#  'thanks',
#  'to',
#  'all',
#  'you',
#  'who',
#  've',
#  'traveled',
#  'from',
#  'far',
#  'and',
#  'wide',
#  'to',
#  'brave',
#  'the',
#  'cold',
#  'today',
#  'we',
#  'all',
#  'made',
#  'this',
#  'journey',
#  'for',
#  'a',
#  'reason',
#  'it',
#  's',
#  'humbling',
#  'but',
#  'in',
#  'my',
#  'heart',
#  'i',
#  'know',
#  'you',
#  'didn',
#  't',
#  'come',
#  'here',
#  'just',
#  'for',
#  'me',
#  'you',
#  'came',
#  'here',
#  'because',
#  'you',
#  'believe',
#  'in',
#  'what',
#  'this',
#  'country',
#  'can',
#  'be',
#  'in',
#  'the',
#  'face',
#  'of',
#  'war',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'peace',
#  'in',
#  'the',
#  'face',
#  'of',
#  'despair',
#  'you',
#  'believe',
#  'there',
#  'can',
#  'be',
#  'hope',
#  'in',
#  'the',
#  'face',
#  'of',
#  'a',
#  'politics',
#  'that',
#  's',
#  'shut',
#  'you',
#  'out',
#  'that',
#  's',
#  'told',
# ...

# %%
#Counter(tokens)
#vocab
